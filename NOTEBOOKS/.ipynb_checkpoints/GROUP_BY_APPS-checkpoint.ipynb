# %%
import pandas as pd

# %%
df = pd.read_excel("sampledatafoodsales.xlsx","FoodSales").head(30)

# %%
df
# Out:
#     OrderDate Region         City  Category         Product  Quantity  \
# 0  2020-01-01   East       Boston      Bars          Carrot        33
# 1  2020-01-04   East       Boston  Crackers     Whole Wheat        87
# 2  2020-01-07   West  Los Angeles   Cookies  Chocolate Chip        58
# 3  2020-01-10   East     New York   Cookies  Chocolate Chip        82
# 4  2020-01-13   East       Boston   Cookies       Arrowroot        38
# 5  2020-01-16   East       Boston      Bars          Carrot        54
# 6  2020-01-19   East       Boston  Crackers     Whole Wheat       149
# 7  2020-01-22   West  Los Angeles      Bars          Carrot        51
# 8  2020-01-25   East     New York      Bars          Carrot       100
# 9  2020-01-28   East     New York    Snacks    Potato Chips        28
# 10 2020-01-31   East       Boston   Cookies       Arrowroot        36
# 11 2020-02-03   East       Boston   Cookies  Chocolate Chip        31
# ...

# %%
g = df.groupby('Category')

# %%
for (key,value_df) in g:
    print('-'*100)
    print('[',key,']')
    print(value_df)
    print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# [ Bars ]
#     OrderDate Region         City Category Product  Quantity  UnitPrice  \
# 0  2020-01-01   East       Boston     Bars  Carrot        33       1.77
# 5  2020-01-16   East       Boston     Bars  Carrot        54       1.77
# 7  2020-01-22   West  Los Angeles     Bars  Carrot        51       1.77
# 8  2020-01-25   East     New York     Bars  Carrot       100       1.77
# 13 2020-02-09   West  Los Angeles     Bars  Carrot        44       1.77
# 14 2020-02-12   East     New York     Bars  Carrot        23       1.77
# 18 2020-02-24   West  Los Angeles     Bars    Bran        42       1.87
# 22 2020-03-08   East       Boston     Bars  Carrot        61       1.77
# 25 2020-03-17   East     New York     Bars  Carrot        38       1.77
# 28 2020-03-26   East       Boston     Bars    Bran       103       1.87
#
#     TotalPrice
# 0        58.41
# 5        95.58
# ...

# %%
g.get_group('Crackers')
# Out:
#     OrderDate Region    City  Category      Product  Quantity  UnitPrice  \
# 1  2020-01-04   East  Boston  Crackers  Whole Wheat        87       3.49
# 6  2020-01-19   East  Boston  Crackers  Whole Wheat       149       3.49
# 12 2020-02-06   East  Boston  Crackers  Whole Wheat        28       3.49
# 23 2020-03-11   East  Boston  Crackers  Whole Wheat        40       3.49
#
#     TotalPrice
# 1       303.63
# 6       520.01
# 12       97.72
# 23      139.60

# %%
g.max()
# Out:
#           OrderDate Region       City         Product  Quantity  UnitPrice  \
# Category
# Bars     2020-03-26   West   New York          Carrot       103       1.87
# Cookies  2020-03-29   West  San Diego  Oatmeal Raisin       193       2.84
# Crackers 2020-03-11   East     Boston     Whole Wheat       149       3.49
# Snacks   2020-03-20   East   New York    Potato Chips        68       1.68
#
#           TotalPrice
# Category
# Bars          192.61
# Cookies       548.12
# Crackers      520.01
# Snacks        114.24

# %%
g.mean()
# Out:
#            Quantity  UnitPrice  TotalPrice
# Category
# Bars      54.900000       1.79   98.623000
# Cookies   67.461538       2.24  157.222308
# Crackers  76.000000       3.49  265.240000
# Snacks    41.000000       1.46   62.830000

# %%
# get all the analytics in one go
g.describe()
# Out:
#          Quantity                                                         \
#             count       mean        std   min   25%   50%     75%    max
# Category
# Bars         10.0  54.900000  26.809824  23.0  39.0  47.5   59.25  103.0
# Cookies      13.0  67.461538  47.419432  30.0  36.0  43.0   85.00  193.0
# Crackers      4.0  76.000000  54.924190  28.0  37.0  63.5  102.50  149.0
# Snacks        3.0  41.000000  23.388031  27.0  27.5  28.0   48.00   68.0
#
#          UnitPrice        ...              TotalPrice                          \
#              count  mean  ...    75%   max      count        mean         std
# Category                  ...
# Bars          10.0  1.79  ...  1.770  1.87       10.0   98.623000   49.363895
# Cookies       13.0  2.24  ...  2.840  2.84       13.0  157.222308  139.657421
# Crackers       4.0  3.49  ...  3.490  3.49        4.0  265.240000  191.685424
# Snacks         3.0  1.46  ...  1.515  1.68        3.0   62.830000   44.527483
#
#
# ...

# %%
# %matplotlib inline
g.plot()
# Out:
# Category
# Bars        AxesSubplot(0.125,0.125;0.775x0.755)
# Cookies     AxesSubplot(0.125,0.125;0.775x0.755)
# Crackers    AxesSubplot(0.125,0.125;0.775x0.755)
# Snacks      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
