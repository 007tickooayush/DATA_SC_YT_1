# %%
import pandas as pd

# %%
df = pd.read_csv("TCS.csv",parse_dates=["Date"])
demo = pd.read_csv('TCS.csv')

# %%
df.set_index("Date",inplace=True)

# %%
df
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00   985.00
# 2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30   976.85
# 2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55   961.20
# 2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00   986.40
# 2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00   987.80
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
df.isna().sum()
# Out:
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1683
# Deliverable Volume       0
# %Deliverble              0
# dtype: int64

# %%
nw_df = df.fillna({
    'Trades':0.0
})

# %%
nw_df
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00   985.00
# 2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30   976.85
# 2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55   961.20
# 2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00   986.40
# 2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00   987.80
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
# a method for carrying forward the values to fill NaN rows
# nw_df = df.fillna(method="ffill")

# a method for carrying previous the values to fill NaN rows
nw_df = df.fillna(method="bfill")
# much more options available for 

nw_df
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00   985.00
# 2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30   976.85
# 2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55   961.20
# 2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00   986.40
# 2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00   987.80
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
# NOT WORKING !!!

# inserting a demo valuefor testing
df[df['Trades'] == None]['2004-08-25'] = 70982.19

# using linear interpolation to fill na values
nw_df = df.interpolate()
# use time to get more relative values
# nw_df = df.interpolate(method="time")
nw_df
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2004-08-25    TCS     EQ      850.00  1198.70  1198.70   979.00   985.00
# 2004-08-26    TCS     EQ      987.95   992.00   997.00   975.30   976.85
# 2004-08-27    TCS     EQ      979.00   982.40   982.40   958.55   961.20
# 2004-08-30    TCS     EQ      962.65   969.90   990.00   965.00   986.40
# 2004-08-31    TCS     EQ      986.75   986.50   990.00   976.00   987.80
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
drop_df = df.dropna()
drop_df
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2011-06-01    TCS     EQ     1157.15  1157.00  1177.00  1157.00  1174.70
# 2011-06-02    TCS     EQ     1175.40  1158.90  1172.00  1156.65  1170.00
# 2011-06-03    TCS     EQ     1167.75  1166.00  1175.00  1150.00  1153.00
# 2011-06-06    TCS     EQ     1152.10  1140.00  1168.00  1140.00  1167.00
# 2011-06-07    TCS     EQ     1164.35  1163.00  1183.15  1158.00  1180.00
# ...           ...    ...         ...      ...      ...      ...      ...
# 2021-04-26    TCS     EQ     3109.50  3102.05  3153.00  3088.05  3100.05
# 2021-04-27    TCS     EQ     3100.80  3106.00  3136.10  3103.00  3132.75
# 2021-04-28    TCS     EQ     3132.00  3149.95  3151.00  3112.00  3123.00
# 2021-04-29    TCS     EQ     3124.10  3145.60  3157.35  3105.50  3114.45
# 2021-04-30    TCS     EQ     3115.25  3099.00  3132.05  3020.00  3040.00
#
#               Close     VWAP   Volume      Turnover    Trades  \
# Date
# ...

# %%
nw_df = df.replace(['TCS'],'TATA')
nw_df

# %%
# column specific replacement 
nw_df = df.replace({
    'Series':'EQ'
},'TEST_REPLACE')
nw_df

# %%
# value specific replacement
nw_df = df.replace({
    'EQ':'TEST_REPLACE'
})
nw_df

# %%
# regex replacement
# default usage =>
# nw_df = df.replace('[A-Za-z]','',regex=True)

nw_df = df.replace({'Series':'[A-Za-z]'},'TEST_REGEX',regex=True)
nw_df

# %%
# replace a list with another list of values
nw_df = df.replace(['TCS','EQ'],['TEST_LIST1','TEST_LIST2'])

nw_df
